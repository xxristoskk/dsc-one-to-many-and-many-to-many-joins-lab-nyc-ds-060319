# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on one-to-many and many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data using one-to-many and many-to-many joins
# - Predict the resulting size of one-to-many and many-to-many joins

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connect to the Database

# %%
#Your code here
import sqlite3
import pandas as pd
conn = sqlite3.connect('data.sqlite')
c = conn.cursor()

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
#Your code here
c.execute('''SELECT employees.firstName, employees.lastName, offices.city, offices.state FROM employees
                            INNER JOIN offices ON offices.officeCode = employees.officeCode''').fetchall()
# Out:
# [('Diane', 'Murphy', 'San Francisco', 'CA'),
#  ('Mary', 'Patterson', 'San Francisco', 'CA'),
#  ('Jeff', 'Firrelli', 'San Francisco', 'CA'),
#  ('William', 'Patterson', 'Sydney', ''),
#  ('Gerard', 'Bondur', 'Paris', ''),
#  ('Anthony', 'Bow', 'San Francisco', 'CA'),
#  ('Leslie', 'Jennings', 'San Francisco', 'CA'),
#  ('Leslie', 'Thompson', 'San Francisco', 'CA'),
#  ('Julie', 'Firrelli', 'Boston', 'MA'),
#  ('Steve', 'Patterson', 'Boston', 'MA'),
#  ('Foon Yue', 'Tseng', 'NYC', 'NY'),
#  ('George', 'Vanauf', 'NYC', 'NY'),
#  ('Loui', 'Bondur', 'Paris', ''),
#  ('Gerard', 'Hernandez', 'Paris', ''),
#  ('Pamela', 'Castillo', 'Paris', ''),
#  ('Larry', 'Bott', 'London', ''),
#  ('Barry', 'Jones', 'London', ''),
#  ('Andy', 'Fixter', 'Sydney', ''),
#  ('Peter', 'Marsh', 'Sydney', ''),
#  ('Tom', 'King', 'Sydney', ''),
#  ('Mami', 'Nishi', 'Tokyo', 'Chiyoda-Ku'),
#  ('Yoshimi', 'Kato', 'Tokyo', 'Chiyoda-Ku'),
#  ('Martin', 'Gerard', 'Paris', '')]

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all the customers first and last names along with a record for each of their order numbers, order dates and statuses.

# %%
# Your code here
c.execute('''SELECT
        customers.contactFirstName, customers.contactLastName, orders.orderNumber, orders.orderDate, orders.status
             FROM customers 
             JOIN orders
             ON orders.customerNumber = customers.customerNumber''').fetchall()
# Out:
# [('Carine ', 'Schmitt', '10123', '2003-05-20', 'Shipped'),
#  ('Carine ', 'Schmitt', '10298', '2004-09-27', 'Shipped'),
#  ('Carine ', 'Schmitt', '10345', '2004-11-25', 'Shipped'),
#  ('Jean', 'King', '10124', '2003-05-21', 'Shipped'),
#  ('Jean', 'King', '10278', '2004-08-06', 'Shipped'),
#  ('Jean', 'King', '10346', '2004-11-29', 'Shipped'),
#  ('Peter', 'Ferguson', '10120', '2003-04-29', 'Shipped'),
#  ('Peter', 'Ferguson', '10125', '2003-05-21', 'Shipped'),
#  ('Peter', 'Ferguson', '10223', '2004-02-20', 'Shipped'),
#  ('Peter', 'Ferguson', '10342', '2004-11-24', 'Shipped'),
#  ('Peter', 'Ferguson', '10347', '2004-11-29', 'Shipped'),
#  ('Janine ', 'Labrune', '10275', '2004-07-23', 'Shipped'),
#  ('Janine ', 'Labrune', '10315', '2004-10-29', 'Shipped'),
#  ('Janine ', 'Labrune', '10375', '2005-02-03', 'Shipped'),
#  ('Janine ', 'Labrune', '10425', '2005-05-31', 'In Process'),
#  ('Jonas ', 'Bergulfsen', '10103', '2003-01-29', 'Shipped'),
# ...

# %% [markdown]
# ## Customers and their Payments (another One-to-Many join)
#
# Return a list of customers first and last names along with details about their payments including the amount and date of payments. Sort these results in descending order by the payment amount.

# %%
# Your code here
c.execute('''SELECT customers.contactFirstName, customers.contactLastName, 
                    payments.amount, payments.paymentDate
             FROM customers
             JOIN payments
             ON payments.customerNumber = customers.customerNumber
             ''').fetchall()
# Out:
# [('Carine ', 'Schmitt', '14571.44', '2003-06-05'),
#  ('Carine ', 'Schmitt', '6066.78', '2004-10-19'),
#  ('Carine ', 'Schmitt', '1676.14', '2004-12-18'),
#  ('Jean', 'King', '32641.98', '2003-06-06'),
#  ('Jean', 'King', '33347.88', '2004-08-20'),
#  ('Jean', 'King', '14191.12', '2004-12-17'),
#  ('Peter', 'Ferguson', '45864.03', '2003-05-20'),
#  ('Peter', 'Ferguson', '7565.08', '2003-05-31'),
#  ('Peter', 'Ferguson', '44894.74', '2004-03-10'),
#  ('Peter', 'Ferguson', '82261.22', '2004-12-15'),
#  ('Janine ', 'Labrune', '47924.19', '2004-08-08'),
#  ('Janine ', 'Labrune', '19501.82', '2004-11-14'),
#  ('Janine ', 'Labrune', '49523.67', '2005-02-22'),
#  ('Jonas ', 'Bergulfsen', '50218.95', '2003-02-16'),
#  ('Jonas ', 'Bergulfsen', '1491.38', '2003-10-28'),
#  ('Jonas ', 'Bergulfsen', '17876.32', '2004-11-04'),
#  ('Jonas ', 'Bergulfsen', '34638.14', '2004-11-28'),
#  ('Susan', 'Nelson', '11044.30', '2003-04-11'),
#  ('Susan', 'Nelson', '111654.40', '2003-08-15'),
# ...

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of customer first and last names, product names, quantities, and date ordered for each of the customers and each of their orders. Sort these in descending order by the order date.
#
# Note: This will require joining 4 tables! This can be tricky! Give it a shot, and if you're still stuck, turn to the next section where you'll see how to write subqueries which can make complex queries such as this much simpler!

# %%
# Your code here
c.execute('''SELECT contactFirstName, contactLastName, productName, orderDate, quantityOrdered
             FROM customers
             JOIN orders
             USING(customerNumber)
             JOIN orderdetails
             USING(orderNumber)
             JOIN products
             USING(productCode)
             ORDER BY orderDate DESC
                ''').fetchall()
# Out:
# [('Janine ', 'Labrune', '1962 LanciaA Delta 16V', '2005-05-31', '38'),
#  ('Janine ', 'Labrune', '1957 Chevy Pickup', '2005-05-31', '33'),
#  ('Janine ', 'Labrune', '1998 Chrysler Plymouth Prowler', '2005-05-31', '28'),
#  ('Janine ', 'Labrune', '1964 Mercedes Tour Bus', '2005-05-31', '38'),
#  ('Janine ', 'Labrune', '1926 Ford Fire Engine', '2005-05-31', '19'),
#  ('Janine ', 'Labrune', '1992 Ferrari 360 Spider red', '2005-05-31', '28'),
#  ('Janine ', 'Labrune', '1940s Ford truck', '2005-05-31', '38'),
#  ('Janine ', 'Labrune', '1970 Dodge Coronet', '2005-05-31', '55'),
#  ('Janine ', 'Labrune', '1962 Volkswagen Microbus', '2005-05-31', '49'),
#  ('Janine ',
#   'Labrune',
#   '1958 Chevy Corvette Limited Edition',
#   '2005-05-31',
#   '31'),
#  ('Janine ', 'Labrune', '1980’s GM Manhattan Express', '2005-05-31', '41'),
#  ('Janine ', 'Labrune', '1954 Greyhound Scenicruiser', '2005-05-31', '11'),
#  ('Janine ',
#   'Labrune',
#   'Diamond T620 Semi-Skirted Tanker',
# ...

# %%
c.execute('''SELECT products.productName, customers.contactFirstName, customers.contactLastName, orders.orderDate,
                    orderdetails.quantityOrdered
             FROM products, customers, orders, orderdetails
             ''').fetchall()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7eac8e5fedc2> in <module>
# ----> 1 c.execute('''SELECT products.productName, customers.contactFirstName, customers.contactLastName, orders.orderDate,
#       2                     orderdetails.quantityOrdered
#       3              FROM products, customers, orders, orderdetails
#       4              ''').fetchall()
#
# NameError: name 'c' is not defined

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on one-to-many and many-to-many relationships!
